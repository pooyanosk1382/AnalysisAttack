# %%
# This program is developed by Pooyan :D

# %% [markdown]
# Now it's time to decrypt the cipher text.
# For this we have to compare the number of letters in books and cipher text and by this way change word.

# %% [markdown]
# By comparing letters we can understand that L in cipher text is equals with e in real letters.
# But if we want to be sure about it, we can put e in place of L in two and three letters and can see that in two letters, TL has the same plenty with he and in three letters ETL has the same plenty with the and, now we are sure about it that L is e so, we can exchange L with e.
# Now we can get it that T is h and E is t.
# In next cell we will change them.

# %%
reader = open('cipherText.txt', 'r')
cipherText = reader.read()
cipherText = cipherText.replace('L', 'e')
cipherText = cipherText.replace('E', 't')
cipherText = cipherText.replace('T', 'h')
print(cipherText)
# Out:
# ...

# %% [markdown]
# Now again we count the letters and two and three letters to find other algos.

# %%
alphabet = ['A', 'B', 'C', 'D', 't', 'F', 'G', 'H', 'I', 'J', 'K', 'e', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
from matplotlib import pyplot as plt

for i in cipherText:
    if i == 'A':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'C':
        alphabetVal[2] += 1
    elif i == 'D':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'F':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'I':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'O':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'R':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('OF', 44104),
#  ('De', 37362),
#  ('eD', 37327),
#  ('CF', 35133),
#  ('eG', 34521),
#  ('tO', 33882),
#  ('IF', 33711),
#  ('It', 33459),
#  ('Ft', 32687),
#  ('eF', 29407),
#  ('FH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('IR', 22868),
#  ('DO', 22845),
#  ('CD', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('eI', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('ID', 21188),
#  ('tC', 20858),
#  ('hI', 20674),
#  ('Ne', 20330),
#  ('OC', 18599),
#  ('OG', 18326),
#  ('eZ', 18244),
#  ('FA', 18234),
#  ('CQ', 17746),
#  ('Ot', 17560),
#  ('Re', 17185),
#  ('ZC', 17039),
#  ('tI', 17009),
#  ('DI', 16635),
#  ('FO', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('HO', 14981),
#  ('Zt', 14887),
#  ('eC', 14638),
#  ('GO', 13779),
#  ('VH', 13075),
#  ('RR', 12841),
#  ('DC', 12609),
#  ('RO', 12551),
#  ('IG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('Ae', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('OCF', 17993),
#  ('tOC', 16535),
#  ('IFH', 13968),
#  ('eFt', 12590),
#  ('OFA', 11147),
#  ('ItO', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('OFt', 9402),
#  ('thI', 9389),
#  ('hIt', 9226),
#  ('HHU', 9200),
#  ('DeG', 8786),
#  ('ZCF', 8362),
#  ('Fte', 8313),
#  ('Ite', 8257),
#  ('Aht', 8252),
#  ('tIF', 8245),
#  ('teD', 8045),
#  ('OAh', 8000),
#  ('FOF', 7907),
#  ('eZt', 7785),
#  ('heD', 7589),
#  ('eDO', 7583),
#  ('CFt', 7491),
#  ('Gth', 7399),
#  ('ZtO', 7308),
#  ('Qth', 7052),
#  ('CQt', 6957),
#  ('GOF', 6939),
#  ('HVH', 6739),
#  ('eID', 6575),
#  ('eGt', 6394),
#  ('DOA', 6341),
#  ('eDe', 6271),
#  ('CFG', 6208),
#  ('eYK', 6151),
#  ('IRR', 5910),
#  ('Hth', 5731),
#  ('JID', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('CDe', 5420),
#  ('eGe', 5362),
#  ('QCD', 5310),
#  ('IDt', 5296),
#  ('tCD', 5284),
#  ('heG', 5196),
#  ('Fth', 5080),
#  ('hhe', 5046),
#  ('IAe', 4950),
#  ('HQH', 4865),
# ...

# %% [markdown]
# By comparing we can understand that OCF is near to ion and OF is near to in and O is near to i and F near to n so, we can replace 'OCF' with 'ion'.

# %%
cipherText = cipherText.replace('O', 'i')
cipherText = cipherText.replace('C', 'o')
cipherText = cipherText.replace('F', 'n')

# %% [markdown]
# Now again we count the letters and two and three letters to find other algos.

# %%
alphabet = ['A', 'B', 'o', 'D', 't', 'n', 'G', 'H', 'I', 'J', 'K', 'e', 'M', 'N', 'i', 'P', 'Q', 'R', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
for i in cipherText:
    if i == 'A':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'o':
        alphabetVal[2] += 1
    elif i == 'D':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'n':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'I':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'i':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'R':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('in', 44104),
#  ('De', 37362),
#  ('eD', 37327),
#  ('on', 35133),
#  ('eG', 34521),
#  ('ti', 33882),
#  ('In', 33711),
#  ('It', 33459),
#  ('nt', 32687),
#  ('en', 29407),
#  ('nH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('IR', 22868),
#  ('Di', 22845),
#  ('oD', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('eI', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('ID', 21188),
#  ('to', 20858),
#  ('hI', 20674),
#  ('Ne', 20330),
#  ('io', 18599),
#  ('iG', 18326),
#  ('eZ', 18244),
#  ('nA', 18234),
#  ('oQ', 17746),
#  ('it', 17560),
#  ('Re', 17185),
#  ('Zo', 17039),
#  ('tI', 17009),
#  ('DI', 16635),
#  ('ni', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('Hi', 14981),
#  ('Zt', 14887),
#  ('eo', 14638),
#  ('Gi', 13779),
#  ('VH', 13075),
#  ('RR', 12841),
#  ('Do', 12609),
#  ('Ri', 12551),
#  ('IG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('Ae', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('ion', 17993),
#  ('tio', 16535),
#  ('InH', 13968),
#  ('ent', 12590),
#  ('inA', 11147),
#  ('Iti', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('int', 9402),
#  ('thI', 9389),
#  ('hIt', 9226),
#  ('HHU', 9200),
#  ('DeG', 8786),
#  ('Zon', 8362),
#  ('nte', 8313),
#  ('Ite', 8257),
#  ('Aht', 8252),
#  ('tIn', 8245),
#  ('teD', 8045),
#  ('iAh', 8000),
#  ('nin', 7907),
#  ('eZt', 7785),
#  ('heD', 7589),
#  ('eDi', 7583),
#  ('ont', 7491),
#  ('Gth', 7399),
#  ('Zti', 7308),
#  ('Qth', 7052),
#  ('oQt', 6957),
#  ('Gin', 6939),
#  ('HVH', 6739),
#  ('eID', 6575),
#  ('eGt', 6394),
#  ('DiA', 6341),
#  ('eDe', 6271),
#  ('onG', 6208),
#  ('eYK', 6151),
#  ('IRR', 5910),
#  ('Hth', 5731),
#  ('JID', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('oDe', 5420),
#  ('eGe', 5362),
#  ('QoD', 5310),
#  ('IDt', 5296),
#  ('toD', 5284),
#  ('heG', 5196),
#  ('nth', 5080),
#  ('hhe', 5046),
#  ('IAe', 4950),
#  ('HQH', 4865),
# ...

# %% [markdown]
# And now it is clear that A is g because inA is near to ing.

# %%
cipherText = cipherText.replace('A', 'g')

# %%
alphabet = ['g', 'B', 'o', 'D', 't', 'n', 'G', 'H', 'I', 'J', 'K', 'e', 'M', 'N', 'i', 'P', 'Q', 'R', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
for i in cipherText:
    if i == 'g':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'o':
        alphabetVal[2] += 1
    elif i == 'D':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'n':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'I':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'i':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'R':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('in', 44104),
#  ('De', 37362),
#  ('eD', 37327),
#  ('on', 35133),
#  ('eG', 34521),
#  ('ti', 33882),
#  ('In', 33711),
#  ('It', 33459),
#  ('nt', 32687),
#  ('en', 29407),
#  ('nH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('IR', 22868),
#  ('Di', 22845),
#  ('oD', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('eI', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('ID', 21188),
#  ('to', 20858),
#  ('hI', 20674),
#  ('Ne', 20330),
#  ('io', 18599),
#  ('iG', 18326),
#  ('eZ', 18244),
#  ('ng', 18234),
#  ('oQ', 17746),
#  ('it', 17560),
#  ('Re', 17185),
#  ('Zo', 17039),
#  ('tI', 17009),
#  ('DI', 16635),
#  ('ni', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('Hi', 14981),
#  ('Zt', 14887),
#  ('eo', 14638),
#  ('Gi', 13779),
#  ('VH', 13075),
#  ('RR', 12841),
#  ('Do', 12609),
#  ('Ri', 12551),
#  ('IG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('ge', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('ion', 17993),
#  ('tio', 16535),
#  ('InH', 13968),
#  ('ent', 12590),
#  ('ing', 11147),
#  ('Iti', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('int', 9402),
#  ('thI', 9389),
#  ('hIt', 9226),
#  ('HHU', 9200),
#  ('DeG', 8786),
#  ('Zon', 8362),
#  ('nte', 8313),
#  ('Ite', 8257),
#  ('ght', 8252),
#  ('tIn', 8245),
#  ('teD', 8045),
#  ('igh', 8000),
#  ('nin', 7907),
#  ('eZt', 7785),
#  ('heD', 7589),
#  ('eDi', 7583),
#  ('ont', 7491),
#  ('Gth', 7399),
#  ('Zti', 7308),
#  ('Qth', 7052),
#  ('oQt', 6957),
#  ('Gin', 6939),
#  ('HVH', 6739),
#  ('eID', 6575),
#  ('eGt', 6394),
#  ('Dig', 6341),
#  ('eDe', 6271),
#  ('onG', 6208),
#  ('eYK', 6151),
#  ('IRR', 5910),
#  ('Hth', 5731),
#  ('JID', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('oDe', 5420),
#  ('eGe', 5362),
#  ('QoD', 5310),
#  ('IDt', 5296),
#  ('toD', 5284),
#  ('heG', 5196),
#  ('nth', 5080),
#  ('hhe', 5046),
#  ('Ige', 4950),
#  ('HQH', 4865),
# ...

# %% [markdown]
# Clearly eD and De are near to re and er and D is near to r.

# %%
cipherText = cipherText.replace('D', 'r')

# %%
alphabet = ['g', 'B', 'o', 'r', 't', 'n', 'G', 'H', 'I', 'J', 'K', 'e', 'M', 'N', 'i', 'P', 'Q', 'R', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
for i in cipherText:
    if i == 'g':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'o':
        alphabetVal[2] += 1
    elif i == 'r':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'n':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'I':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'i':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'R':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('in', 44104),
#  ('re', 37362),
#  ('er', 37327),
#  ('on', 35133),
#  ('eG', 34521),
#  ('ti', 33882),
#  ('In', 33711),
#  ('It', 33459),
#  ('nt', 32687),
#  ('en', 29407),
#  ('nH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('IR', 22868),
#  ('ri', 22845),
#  ('or', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('eI', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('Ir', 21188),
#  ('to', 20858),
#  ('hI', 20674),
#  ('Ne', 20330),
#  ('io', 18599),
#  ('iG', 18326),
#  ('eZ', 18244),
#  ('ng', 18234),
#  ('oQ', 17746),
#  ('it', 17560),
#  ('Re', 17185),
#  ('Zo', 17039),
#  ('tI', 17009),
#  ('rI', 16635),
#  ('ni', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('Hi', 14981),
#  ('Zt', 14887),
#  ('eo', 14638),
#  ('Gi', 13779),
#  ('VH', 13075),
#  ('RR', 12841),
#  ('ro', 12609),
#  ('Ri', 12551),
#  ('IG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('ge', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('ion', 17993),
#  ('tio', 16535),
#  ('InH', 13968),
#  ('ent', 12590),
#  ('ing', 11147),
#  ('Iti', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('int', 9402),
#  ('thI', 9389),
#  ('hIt', 9226),
#  ('HHU', 9200),
#  ('reG', 8786),
#  ('Zon', 8362),
#  ('nte', 8313),
#  ('Ite', 8257),
#  ('ght', 8252),
#  ('tIn', 8245),
#  ('ter', 8045),
#  ('igh', 8000),
#  ('nin', 7907),
#  ('eZt', 7785),
#  ('her', 7589),
#  ('eri', 7583),
#  ('ont', 7491),
#  ('Gth', 7399),
#  ('Zti', 7308),
#  ('Qth', 7052),
#  ('oQt', 6957),
#  ('Gin', 6939),
#  ('HVH', 6739),
#  ('eIr', 6575),
#  ('eGt', 6394),
#  ('rig', 6341),
#  ('ere', 6271),
#  ('onG', 6208),
#  ('eYK', 6151),
#  ('IRR', 5910),
#  ('Hth', 5731),
#  ('JIr', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('ore', 5420),
#  ('eGe', 5362),
#  ('Qor', 5310),
#  ('Irt', 5296),
#  ('tor', 5284),
#  ('heG', 5196),
#  ('nth', 5080),
#  ('hhe', 5046),
#  ('Ige', 4950),
#  ('HQH', 4865),
# ...

# %% [markdown]
# We have It and In and Ige and Ite and eIr and eI that we can guess I is a.

# %%
cipherText = cipherText.replace('I', 'a')

# %%
alphabet = ['g', 'B', 'o', 'r', 't', 'n', 'G', 'H', 'a', 'J', 'K', 'e', 'M', 'N', 'i', 'P', 'Q', 'R', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
for i in cipherText:
    if i == 'g':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'o':
        alphabetVal[2] += 1
    elif i == 'r':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'n':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'a':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'i':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'R':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('in', 44104),
#  ('re', 37362),
#  ('er', 37327),
#  ('on', 35133),
#  ('eG', 34521),
#  ('ti', 33882),
#  ('an', 33711),
#  ('at', 33459),
#  ('nt', 32687),
#  ('en', 29407),
#  ('nH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('aR', 22868),
#  ('ri', 22845),
#  ('or', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('ea', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('ar', 21188),
#  ('to', 20858),
#  ('ha', 20674),
#  ('Ne', 20330),
#  ('io', 18599),
#  ('iG', 18326),
#  ('eZ', 18244),
#  ('ng', 18234),
#  ('oQ', 17746),
#  ('it', 17560),
#  ('Re', 17185),
#  ('Zo', 17039),
#  ('ta', 17009),
#  ('ra', 16635),
#  ('ni', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('Hi', 14981),
#  ('Zt', 14887),
#  ('eo', 14638),
#  ('Gi', 13779),
#  ('VH', 13075),
#  ('RR', 12841),
#  ('ro', 12609),
#  ('Ri', 12551),
#  ('aG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('ge', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('ion', 17993),
#  ('tio', 16535),
#  ('anH', 13968),
#  ('ent', 12590),
#  ('ing', 11147),
#  ('ati', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('int', 9402),
#  ('tha', 9389),
#  ('hat', 9226),
#  ('HHU', 9200),
#  ('reG', 8786),
#  ('Zon', 8362),
#  ('nte', 8313),
#  ('ate', 8257),
#  ('ght', 8252),
#  ('tan', 8245),
#  ('ter', 8045),
#  ('igh', 8000),
#  ('nin', 7907),
#  ('eZt', 7785),
#  ('her', 7589),
#  ('eri', 7583),
#  ('ont', 7491),
#  ('Gth', 7399),
#  ('Zti', 7308),
#  ('Qth', 7052),
#  ('oQt', 6957),
#  ('Gin', 6939),
#  ('HVH', 6739),
#  ('ear', 6575),
#  ('eGt', 6394),
#  ('rig', 6341),
#  ('ere', 6271),
#  ('onG', 6208),
#  ('eYK', 6151),
#  ('aRR', 5910),
#  ('Hth', 5731),
#  ('Jar', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('ore', 5420),
#  ('eGe', 5362),
#  ('Qor', 5310),
#  ('art', 5296),
#  ('tor', 5284),
#  ('heG', 5196),
#  ('nth', 5080),
#  ('hhe', 5046),
#  ('age', 4950),
#  ('HQH', 4865),
# ...

# %% [markdown]
# By aRR and RR and aR we can guess that R is l.

# %%
cipherText = cipherText.replace('R', 'l')

# %%
alphabet = ['g', 'B', 'o', 'r', 't', 'n', 'G', 'H', 'a', 'J', 'K', 'e', 'M', 'N', 'i', 'P', 'Q', 'l', 'S', 'h', 'U', 'V', 'W', 'X', 'Y', 'Z']
alphabetVal = [0] * 26

# %%
for i in cipherText:
    if i == 'g':
        alphabetVal[0] += 1
    elif i == 'B':
        alphabetVal[1] += 1
    elif i == 'o':
        alphabetVal[2] += 1
    elif i == 'r':
        alphabetVal[3] += 1
    elif i == 't':
        alphabetVal[4] += 1
    elif i == 'n':
        alphabetVal[5] += 1
    elif i == 'G':
        alphabetVal[6] += 1
    elif i == 'H':
        alphabetVal[7] += 1
    elif i == 'a':
        alphabetVal[8] += 1
    elif i == 'J':
        alphabetVal[9] += 1
    elif i == 'K':
        alphabetVal[10] += 1
    elif i == 'e':
        alphabetVal[11] += 1
    elif i == 'M':
        alphabetVal[12] += 1
    elif i == 'N':
        alphabetVal[13] += 1
    elif i == 'i':
        alphabetVal[14] += 1
    elif i == 'P':
        alphabetVal[15] += 1
    elif i == 'Q':
        alphabetVal[16] += 1
    elif i == 'l':
        alphabetVal[17] += 1
    elif i == 'S':
        alphabetVal[18] += 1
    elif i == 'h':
        alphabetVal[19] += 1
    elif i == 'U':
        alphabetVal[20] += 1
    elif i == 'V':
        alphabetVal[21] += 1
    elif i == 'W':
        alphabetVal[22] += 1
    elif i == 'X':
        alphabetVal[23] += 1
    elif i == 'Y':
        alphabetVal[24] += 1
    elif i == 'Z':
        alphabetVal[25] += 1
plt.plot(alphabet, alphabetVal)
plt.title('number of letters in cipher text')
# Out:
# Text(0.5, 1.0, 'number of letters in cipher text')

# %%
twoLetters = {}
for i in range(1, 2581882):
    st = cipherText[i-1] + cipherText[i]
    if twoLetters.get(st) is not None:
        twoLetters.__setitem__(st, twoLetters.get(st)+1)
    else:
        twoLetters.__setitem__(st, 1)
sorted(twoLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('HH', 65195),
#  ('th', 60959),
#  ('he', 52042),
#  ('in', 44104),
#  ('re', 37362),
#  ('er', 37327),
#  ('on', 35133),
#  ('eG', 34521),
#  ('ti', 33882),
#  ('an', 33711),
#  ('at', 33459),
#  ('nt', 32687),
#  ('en', 29407),
#  ('nH', 28637),
#  ('HU', 27284),
#  ('te', 25969),
#  ('UH', 24718),
#  ('al', 22868),
#  ('ri', 22845),
#  ('or', 22766),
#  ('eH', 22655),
#  ('et', 21913),
#  ('ea', 21830),
#  ('Gt', 21756),
#  ('Ge', 21404),
#  ('ar', 21188),
#  ('to', 20858),
#  ('ha', 20674),
#  ('Ne', 20330),
#  ('io', 18599),
#  ('iG', 18326),
#  ('eZ', 18244),
#  ('ng', 18234),
#  ('oQ', 17746),
#  ('it', 17560),
#  ('le', 17185),
#  ('Zo', 17039),
#  ('ta', 17009),
#  ('ra', 16635),
#  ('ni', 16040),
#  ('Ht', 15546),
#  ('ee', 15263),
#  ('Hi', 14981),
#  ('Zt', 14887),
#  ('eo', 14638),
#  ('Gi', 13779),
#  ('VH', 13075),
#  ('ll', 12841),
#  ('ro', 12609),
#  ('li', 12551),
#  ('aG', 12361),
#  ('He', 12230),
#  ('Be', 11587),
#  ('ge', 11582),
#  ('ht', 11579),
# ...

# %%
threeLetters = {}
for i in range(2, 2581882):
    st = cipherText[i-2] + cipherText[i-1] + cipherText[i]
    if threeLetters.get(st) is not None:
        threeLetters.__setitem__(st, threeLetters.get(st)+1)
    else:
        threeLetters.__setitem__(st, 1)
sorted(threeLetters.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('the', 41844),
#  ('HHH', 27709),
#  ('HUH', 18057),
#  ('ion', 17993),
#  ('tio', 16535),
#  ('anH', 13968),
#  ('ent', 12590),
#  ('ing', 11147),
#  ('ati', 10453),
#  ('UHH', 9828),
#  ('eth', 9525),
#  ('int', 9402),
#  ('tha', 9389),
#  ('hat', 9226),
#  ('HHU', 9200),
#  ('reG', 8786),
#  ('Zon', 8362),
#  ('nte', 8313),
#  ('ate', 8257),
#  ('ght', 8252),
#  ('tan', 8245),
#  ('ter', 8045),
#  ('igh', 8000),
#  ('nin', 7907),
#  ('eZt', 7785),
#  ('her', 7589),
#  ('eri', 7583),
#  ('ont', 7491),
#  ('Gth', 7399),
#  ('Zti', 7308),
#  ('Qth', 7052),
#  ('oQt', 6957),
#  ('Gin', 6939),
#  ('HVH', 6739),
#  ('ear', 6575),
#  ('eGt', 6394),
#  ('rig', 6341),
#  ('ere', 6271),
#  ('onG', 6208),
#  ('eYK', 6151),
#  ('all', 5910),
#  ('Hth', 5731),
#  ('Jar', 5717),
#  ('HtH', 5565),
#  ('tth', 5423),
#  ('ore', 5420),
#  ('eGe', 5362),
#  ('Qor', 5310),
#  ('art', 5296),
#  ('tor', 5284),
#  ('heG', 5196),
#  ('nth', 5080),
#  ('hhe', 5046),
#  ('age', 4950),
#  ('HQH', 4865),
# ...
